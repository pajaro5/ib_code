# %% [markdown]
# # 🍗 Taller Interactivo: El Arquitecto de Software de *Los Pollos Hermanos*
#
# **Rol:** Eres el nuevo **Jefe de Seguridad Informática** de *Los Pollos Hermanos*.
# **Misión:** Proteger los datos de los empleados utilizando **Encapsulamiento**.

# %% [markdown]
# ## 🛑 Parte 1: El Problema (Sistema Vulnerable)
#
# El sistema actual permite modificar información sensible sin restricciones.

# %%
class EmpleadoVulnerable:
    def __init__(self, nombre, id_empleado, salario):
        self.nombre = nombre
        self.id_empleado = id_empleado
        self.salario = salario

    def mostrar_info(self):
        print(f"🐔 Empleado: {self.nombre} | ID: {self.id_empleado} | Salario: ${self.salario}")

walter = EmpleadoVulnerable("Walter White", 101, 50000)
walter.mostrar_info()

pepe = EmpleadoVulnerable("pepe", 102, 10000)
pepe.mostrar_info()
# Out:
# 🐔 Empleado: Walter White | ID: 101 | Salario: $50000
# 🐔 Empleado: pepe | ID: 102 | Salario: $10000

# %% [markdown]
# ## 💥 El Sabotaje
# Los atributos públicos permiten alterar datos críticos.

# %%
print("--- INICIANDO SABOTAJE ---")
walter.salario = -999999
walter.nombre = "Heisenberg el Quebrado"
walter.mostrar_info()

pepe.salario = -10
pepe.nombre = "pobre pepe"
pepe.mostrar_info()
# Out:
# --- INICIANDO SABOTAJE ---
# 🐔 Empleado: Heisenberg el Quebrado | ID: 101 | Salario: $-999999
# 🐔 Empleado: pobre pepe | ID: 102 | Salario: $-10

# %% [markdown]
# ## 🛡️ Parte 2: La Solución (Encapsulamiento)
# Usamos atributos privados, getters y setters.

# %%
class EmpleadoSeguro:
    cantidad_empleados = 0  #variable estática

    def __init__(self, nombre, salario):
        self.nombre = nombre
        self.__salario = salario
        EmpleadoSeguro.cantidad_empleados += 1

    def get_salario(self):
        return self.__salario

    def set_salario(self, nuevo_monto):
        if nuevo_monto > 0:
            self.__salario = nuevo_monto
            print(f"✅ Salario actualizado a ${self.__salario}")
        else:
            print("🚫 ERROR DE SEGURIDAD")

mike = EmpleadoSeguro("Mike Ehrmantraut", 200000)


alberto = EmpleadoSeguro("Albertosaurio", 10000)

# %%
# Para habilitar debug presiona Ctrl + Shift + Alt + Enter
try:
    print(mike.__salario)
except AttributeError:
    print("🛡️ Acceso bloqueado.")

#mike.set_salario(-5000)
#mike.set_salario(250000)
#print(mike.get_salario())

try:
    print(alberto.__salario)
except AttributeError:
    print("Acceso Bloqueado 2")

alberto.set_salario(-5000)
# Out:
# 🛡️ Acceso bloqueado.
# Acceso Bloqueado 2
# 🚫 ERROR DE SEGURIDAD

# %% [markdown]
# ## 🧠 Desafío: El Vendedor
# Implementa herencia y encapsulamiento.

# %%
class Vendedor(EmpleadoSeguro):
    def __init__(self, nombre, salario, comision_inicial):
        super().__init__(nombre, salario)
        self.__comision = comision_inicial

    def set_comision(self, valor):
        if 0.0 <= valor <= 1.0:
            self.__comision = valor
            print(f"✅ Comisión: {valor * 100}%")
        else:
            print("🚫 Comisión inválida")

# %%
# Para habilitar debug presiona Ctrl + Shift + Alt + Enter
print(f"Total empleados: {EmpleadoSeguro.cantidad_empleados}")
# Out:
# Total empleados: 1

# %% [markdown]
# ## 📚 Resumen: La Caja de Herramientas de Seguridad (B3)
#
# Antes de irnos, repacemos las herramientas que acabamos de construir. Como arquitectos de software, hemos tomado decisiones de diseño específicas para proteger a *Los Pollos Hermanos*.
#
# ### 1. Encapsulamiento (B3.1.5)
# Es la técnica de **ocultar** los detalles internos de un objeto para proteger su integridad.
# *   **El Problema:** Si dejamos todo público, cualquiera puede poner un salario negativo (`walter.salario = -50`).
# *   **La Solución:** Hacemos los atributos **privados** y usamos métodos para controlarlos.
#
# | Concepto | Código Python | ¿Qué hace? | Analogía |
# | :--- | :--- | :--- | :--- |
# | **Público** | `self.nombre` | Cualquiera puede leerlo y cambiarlo. | Una etiqueta en la camisa. |
# | **Privado** | `self.__salario` | Solo el propio objeto puede tocarlo. | El dinero en la caja fuerte. |
# | **Getter** | `get_salario()` | Permite **leer** el valor privado. | La ventanilla para ver el saldo. |
# | **Setter** | `set_salario()` | Permite **cambiar** el valor (con reglas). | El guardia que valida si puedes entrar. |
#
# ### 2. Alcance de las Variables (B3.1.3)
# Hemos visto que no todas las variables son iguales. Algunas pertenecen a la persona y otras a la empresa.
#
# *   **Variable de Instancia (Dinámica):**
#     *   **Código:** `self.nombre = ...` (dentro del `__init__`).
#     *   **Comportamiento:** Cada objeto tiene su propia copia. Si Walter cambia su nombre, no afecta a Mike.
#     *   **Ejemplo:** El ID del empleado, el sueldo individual.
#
# *   **Variable de Clase (Estática):**
#     *   **Código:** `cantidad_empleados = 0` (definida al inicio de la clase, fuera de los métodos).
#     *   **Comportamiento:** Es compartida por **todos**. Si cambia, cambia para todos.
#     *   **Ejemplo:** El contador total de empleados de la empresa, el nombre de la compañía ("Los Pollos Hermanos"), la tasa de impuestos global.
#
# ---
# > **Regla de oro:** Usa `Setters` para proteger datos sensibles y variables `Estáticas` para datos que son comunes a toda la empresa.

# %% [markdown]
# ## 📝 Reflexión Final
# 1. ¿Por qué es peligroso tener atributos públicos?
# 2. Diferencia entre variable de instancia y estática.
